# %%
import pandas as pd
import numpy as np

import re
from __future__ import division

# %%
import requests
RESULTS = list();
def evaluate(csv):
    url = "http://gorilla.bigdama.tu-berlin.de:8001/DataCleaningEvaluator/"
    r = requests.post(url, data={"value": csv})
    if r.status_code != 200:
            print "There is an error! The error code:", r.status_code
    print r.text
    RESULTS.append(r.text)
    return r.text

# %% [markdown]
# # Task 1
# ## Error Detection
#
# Here, we want to only detect data errors. To mark a cell as data error, you just need to
# change its value into something else.
# - Which of the mentioned data quality constraints can help you to detect data errors?
# How?
# - Report your best error detection precision, recall, and F1.

# %% [markdown]
# There are some desired data quality constraints for the dataset:
# 1. All alphabetical characters in all columns should be capitalized.
# 2. Address data should be compatible to the standard in https://tools.usps.com/go/ZipLookupAction!input.action
# 3. The State column should contain the correct two character US state code.
# 4. City column should contain real city names.
# 5. ZIP column should be formatted as a 5 digit value.
# 6. SSN column should contain an 8-10 digit value.
# Note that, you do not need to fix the DOB, POBox, and POCityStateZip columns.

# %%
df = pd.read_csv("./inputDB.csv")
print df.shape
f = open('us_cities.txt', 'r')
c = f.readlines()
cities = [str(city).rstrip().upper() for city in c]
reZIP = re.compile('[A-Z a-z]*(\d{5})')
reSSN = re.compile('^(\d{3}-\d{2}-\d{4})|(\d{3}\d{2}\d{4})|\d{8}|\d{9}|\d{10}$')

# %%
#Rule 4 5 6 What if the City,SSN or ZIP is NaN ? Is this an error ?
#df['City'] =df['City'].fillna('ERROR')
#df['SSN'] =df['SSN'].fillna('ERROR')
#df['ZIP'] =df['ZIP'].fillna('ERROR')
reSSN.match("23334245")

# %%
states_list = ( 'AL', 'AK', 'AS', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FM', 'FL', 'GA', 'GU', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MH', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'MP', 'OH', 'OK', 'OR', 'PW', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VI', 'VA', 'WA', 'WV', 'WI', 'WY' )
df = pd.read_csv("./inputDB.csv")

is_capitalized = lambda x: x if str(x).upper() in str(x) else "ERROR"
is_properStateCode = lambda x: x if str(x).upper()  in states_list else "ERROR"
is_properCity = lambda x: x if str(x).upper()  in cities else "ERROR"
is_properZIP = lambda x: x if  reZIP.match(str(x)) else "ERROR"
is_properSSN = lambda x: x if  reSSN.match(str(x)) else "ERROR"

df['FirstName'] = df['FirstName'].map(is_capitalized)
df['MiddleName'] = df['MiddleName'].map(is_capitalized)
df['LastName'] = df['LastName'].map(is_capitalized)

df['SSN'] = df['SSN'].map(is_properSSN)
df['City'] = df['City'].map(is_properCity).map(is_capitalized)
df['ZIP'] = df['ZIP'].map(is_properZIP)
#df['Address'] = df['Address'].map(is_capitalized)


df['State'] = df['State'].map(is_properStateCode).map(is_capitalized)





test = df.to_csv(index=False)
df.sample(100)
# Out:
#          RecID FirstName MiddleName       LastName  \
# 89141  A993835     ERROR      ERROR          ERROR
# 38413  A943107     DAVID          P         BETHAN
# 65220  A969914     ERROR          L          ERROR
# 63198  A967892     GLORY          T      KOUBAISSI
# 81183  A985877   KENNETH      ERROR           NAVA
# 58585  A963279     SUSAN          L         ENELLA
# 5714   A910408         H          G         OLIVER
# 71618  A976312     ERROR      ERROR          ERROR
# 51648  A956342      LUIS          E       THOMPSON
# 64905  A969599      SINA          C  LECOURTURPIER
# 34312  A939006     ERROR      ERROR          ERROR
# 50797  A955491     ERROR      ERROR          ERROR
# 82064  A986758      DAWN          S      CELESTINO
# 7625   A912319     ERROR      ERROR          ERROR
# 11151  A915845     WENDY          V         LEVEHN
# 68453  A973147         A      ERROR          ERROR
# 766    A905460     ERROR      ERROR          ERROR
# 43299  A947993     ERROR      ERROR          ERROR
# 46554  A951248     ERROR      ERROR          ERROR
# 62449  A967143   CHARLES      ERROR      VELAZQUEZ
# 50271  A954965  BENJAMIN          E        JOHNSON
# 1820   A906514     ERROR      ERROR          ERROR
# 37660  A942354     ERROR          D              L
# 19295  A923989      EMMA          N          NIDYE
# 42867  A947561     ERROR          L          ERROR
# 22174  A926868    NOOTOY      ERROR          RAMOS
# 79654  A984348     ERROR      ERROR          ERROR
# 55211  A959905     ERROR      ERROR          ERROR
# 6957   A911651     ERROR      ERROR          ERROR
# 57101  A961795      JILL          B           LIMA
# ...        ...       ...        ...            ...
# 21845  A926539    ADOLFO      ERROR        MASRRUA
# 12003  A916697         C      ERROR          ERROR
# 81860  A986554     ERROR      ERROR          ERROR
# 18338  A923032   BELINDA          M          BEDYA
# 58066  A962760      MAKR          W         BROOME
# 35734  A940428     ERROR      ERROR          ERROR
# 13133  A917827    MADDIE          D         HOWELL
# 76782  A981476     ERROR      ERROR          ERROR
# 37554  A942248    JUDIHT          J        ASBERRY
# 15327  A920021     KAREN      ERROR          EDDAS
# 31337  A936031      JUNE          A          BROWN
# 13552  A918246     ERROR      ERROR          ERROR
# 58129  A962823     ERROR      ERROR          ERROR
# 32006  A936700     ERROR          M          ERROR
# 74683  A979377   DOUGLAS          L           GEER
# 41160  A945854   MAUREEN          R    MIDDLEBROOK
# 44364  A949058    JOSHUA     WARREN          DAVIS
# 125    A904819     ERROR          E          ERROR
# 21477  A926171     ERROR      ERROR          ERROR
# 62329  A967023         R      ERROR          ERROR
# 74454  A979148     ERROR      ERROR          ERROR
# 73019  A977713      BILL          P         RENDON
# 69645  A974339     ERROR      ERROR          ERROR
# 75019  A979713     ERROR      ERROR          ERROR
# 11674  A916368  PATRIICA          J         THAYER
# 71274  A975968     ERROR      ERROR          ERROR
# 68484  A973178     ERROR      ERROR          ERROR
# 65536  A970230     SARAH          C        MORALES
# 367    A905061     ERROR      ERROR          ERROR
# 55885  A960579     ERROR          L          ERROR
#
#                              Address          City  State  \
# 89141             802 W ARLEN NCOURT         ERROR  ERROR
# 38413                  165 weaver rd         ERROR  ERROR
# 65220         3055 TREAT BLVD APT 16         ERROR  ERROR
# 63198     1618 S LOWER SACRAMENTO RD         ERROR     CA
# 81183            1828 CHATEAU DDR E,    CLEARWATER     FL
# 58585      5570 whispering willow wy         ERROR  ERROR
# 5714            200 MILFORD POINT RD         ERROR  ERROR
# 71618                1415 Hayden Ave         ERROR     CA
# 51648           2810 Mi Tierra Drive         ERROR  ERROR
# 64905          2502 Little Forest Ct         ERROR     TX
# 34312               259 e gum log rd         ERROR     AR
# 50797                  3300 YOUNG ST         ERROR  ERROR
# 82064        14300 CLINTON ST SPC 43         ERROR  ERROR
# 7625               221 sundance ircl         ERROR  ERROR
# 11151               1350 Pkyramid Dr         ERROR     AR
# 68453              44708 ROSARIO AVE         ERROR  ERROR
# 766                  2135 twaine cir         ERROR  ERROR
# 43299      2706 W AHLAN AVNUE SPC 14        FRESNO  ERROR
# 46554  3530 w hillsboro blvd apt 205         ERROR  ERROR
# 62449          574 SOUTH BACKTON AVE         ERROR  ERROR
# 50271                   636 MORSE ST         ERROR  ERROR
# 1820                 1141 s bowie dr       ABILENE     TX
# 37660         1060 port esullivan dr         ERROR  ERROR
# 19295              226 wilshire driv         ERROR     FL
# 42867    9010 Sw 125th Ave Apt G-309         ERROR  ERROR
# 22174             1869 N REDDING WAY         ERROR     CA
# 79654              12807 WESTPARK DR       HOUSTON     TX
# 55211  4167 HAVERHILL RD N, APT 1105         ERROR  ERROR
# 6957              525 hiddencrest ct       CONCORD     CA
# 57101         3196 N JOG RD APT 6208         ERROR  ERROR
# ...                              ...           ...    ...
# 21845     1218 mcgirts creek driv w,  JACKSONVILLE     FL
# 12003     209 baltimore avn apt 2t03    HUNTINGTON  ERROR
# 81860               21H0 VIA PROMESA         ERROR  ERROR
# 18338                    110 BWEN RD         ERROR  ERROR
# 58066               1272 LEAVINVS RD         ERROR  ERROR
# 35734         1455 Arnold Drv Apt 18         ERROR     CA
# 13133               7670 EL CERRO DR         ERROR  ERROR
# 76782              154 CHESAPEAKE LN         ERROR  ERROR
# 37554        4898 nw 29th ct apt 307         ERROR  ERROR
# 15327                  8938 isora st         ERROR  ERROR
# 31337          1885 WALNUT ST APT 46         ERROR  ERROR
# 13552                1332 CHURING DR         ERROR  ERROR
# 58129            9457 pam tree drive         ERROR  ERROR
# 32006                2125 Ne 7th Ter         ERROR  ERROR
# 74683              35 SW SAGINAW AVE         ERROR  ERROR
# 41160               1251 Granada Ave         ERROR  ERROR
# 44364           7144 ryan taylor way         ERROR  ERROR
# 125                  3782 falcon div         ERROR  ERROR
# 21477       1437 fuerte heights lane         ERROR  ERROR
# 62329              81 TALLAHASSEE AV         ERROR  ERROR
# 74454        550 1ST AVE S, APT 1007         ERROR  ERROR
# 73019                 3172 Ne 3rd Dr         ERROR  ERROR
# 69645                1028 HANOVER LN         ERROR  ERROR
# 75019                6200 BEEMAN AVE         ERROR  ERROR
# 11674            5656 W 63rd Streetl         ERROR  ERROR
# 71274              2555 PHANTOM LACE         ERROR  ERROR
# 68484                 797 CENTER AVE         ERROR  ERROR
# 65536   13181 Looking Glass Falls Ln         ERROR  ERROR
# 367                     1312 DOMADOR         ERROR  ERROR
# 55885       12590 Ne 16th Av Apt 408         ERROR  ERROR
#
#                        ZIP                POBox  \
# 89141                93277     POST OFFICE 7838
# 38413                71635                  NaN
# 65220                94518          PO BOX 5853
# 63198               L95242                  NaN
# 81183                33756                  NaN
# 58585             fl 33908                  NaN
# 5714             FLY 32952                  NaN
# 71618                93230                  NaN
# 51648                78596                  NaN
# 64905                77373                  NaN
# 34312                72802          Caller 1354
# 50797                ERROR                  NaN
# 82064     CALIFORNIA 92843  POST OFFICE BOX 157
# 7625                 78552                  NaN
# 11151                72034                  NaN
# 68453                93535                  NaN
# 766               CA 94577                  NaN
# 43299                ERROR          PO BOX 5991
# 46554        FLORIDA 33073                  NaN
# 62449           cali 91744           O BOX 3671
# 50271             Ca 94112         PO OX 280911
# 1820                 79605                  NaN
# 37660             TX 75068          buzonr 1021
# 19295                34698                  NaN
# 42867                33186                  NaN
# 22174                91784           po box 671
# 79654                77082                  NaN
# 55211       beach fl 33417                  NaN
# 6957                 94521         PO BOX 5G853
# 57101       BEACH FL 33411           POST 19053
# ...                    ...                  ...
# 21845                32221                  NaN
# 12003             CA 92648                  NaN
# 81860           Cali 93446                  NaN
# 18338                ERROR                  NaN
# 58066                32464                  NaN
# 35734                94553         Po Bvox 1355
# 13133           cali 90620                  NaN
# 76782                94949                  NaN
# 37554                ERROR                  NaN
# 15327            CAS 90660          CPO BOX 100
# 31337             CA 96080                  NaN
# 13552          Texas 78245         Aptdo 690362
# 58129                34786                  NaN
# 32006                ERROR                  NaN
# 74683  LUCIE FLORIDA 34953                  NaN
# 41160                93906         PO BOMX 1931
# 44364     CALIFORNIA 95621            PTDO 1466
# 125                  32046           PO BOX 614
# 21477             Ca 92019          Po Box 2071
# 62329             fl 32355                  NaN
# 74454             Fl 33701         PO BOX 15632
# 73019                33033           POST 24571
# 69645             FL 32081                  NaN
# 75019                ERROR                  NaN
# 11674                ERROR         PO BX 881605
# 71274           CALI 91950          PO BOX 2297
# 68484                94553          po box 1355
# 65536                ERROR        Po Box 720506
# 367               CA 92673                  NaN
# 55885             FL 33161                  NaN
#
#                       POCityStateZip          SSN        DOB
# 89141             Visalia, Cja 93290        ERROR        NaN
# 38413                            NaN    131632970        NaN
# 65220           CONCORD, CALIF. 9424        ERROR   01-08-65
# 63198                            NaN    154345248        NaN
# 81183                            NaN     26876962       1913
# 58585                            NaN  179-50-8971        NaN
# 5714                             NaN        ERROR        NaN
# 71618                            NaN        ERROR        NaN
# 51648                            NaN     50814141        NaN
# 64905                            NaN    157910924       1962
# 34312         Russellville, Ar 72811    162984204        NaN
# 50797                            NaN  194-08-4294        NaN
# 82064          Garden Grove, Ca 9842        ERROR        NaN
# 7625                             NaN  094-83-0168        NaN
# 11151                            NaN        ERROR        NaN
# 68453                            NaN  185-98-9971        NaN
# 766                              NaN        ERROR       1924
# 43299              FRESNEO, CA 93755    110117267        NaN
# 46554                            NaN  050-33-9349        NaN
# 62449            LA PUENTE, CA 91744  157-96-6468        NaN
# 50271        San Francisco, Ca 94128        ERROR        NaN
# 1820                             NaN     43733547    8/24/57
# 37660       Little Eelm, Texas 75068    199636069        NaN
# 19295                            NaN  017-60-8009        NaN
# 42867                            NaN    158050227   04-11-41
# 22174               upland, ca 91785  197-02-7500        NaN
# 79654                            NaN  043-93-4601       1956
# 55211                            NaN  169-01-0130        NaN
# 6957              concorod, ca 94524     17136527  23-Jul-71
# 57101      WEST PALM BEACH, FL 33416  086-22-4451        NaN
# ...                              ...          ...        ...
# 21845                            NaN     18502193        NaN
# 12003                            NaN    171201245        NaN
# 81860                            NaN    112233474        NaN
# 18338                            NaN     80165409        NaN
# 58066                            NaN    162321199        NaN
# 35734             martinez, ca 94553  134-58-0016        NaN
# 13133                            NaN    128408086        NaN
# 76782                            NaN    164821159   19691104
# 37554                            NaN  707-85-0104        NaN
# 15327  PICO RIVERA, CALIFORNIA 90660        ERROR        NaN
# 31337                            NaN  015-91-7956        NaN
# 13552          SAN ANTONIO, TX 78269        ERROR        NaN
# 58129                            NaN     21426504        NaN
# 32006                            NaN  000-54-0706       1901
# 74683                            NaN  171-62-9555        NaN
# 41160              salinas, ca 93902        ERROR        NaN
# 44364       citrus heights, ca 95611     60956750       1916
# 125               HILLIARD, FL 32046    616299483        NaN
# 21477         EL CAJON, CALIF. 92021    149566855       1954
# 62329                            NaN     37136645        NaN
# 74454  Saint Petersfburg, Fla. 33733        ERROR        NaN
# 73019            homestead, fl 33092    131692217        NaN
# 69645                            NaN        ERROR    6/21/03
# 75019                            NaN     93108372   05-02-59
# 11674          Los Angeles, Ca 90009  022-60-3777        NaN
# 71274        national city, ca 91951        ERROR       1987
# 68484              MARTINEZ, CA 9453     93032734       1986
# 65536          Orlando, Floida 32872    148374937        NaN
# 367                              NaN        ERROR        NaN
# 55885                            NaN  161-68-6129        NaN
#
# [100 rows x 12 columns]

# %%
evaluate(test)
# Out:
# Number of dirty cells: 388126 (Number of erroneous cells in the data)
# -----------------Error Detection Results-----------------
# Number of detected cells: 328009 (Number of changed values)
# Number of Correctly Detected cells: 255241 (cell was correctly identified as an error)
# Detection precision: 0.778152428744 (ratio of correctly detected cells over all detected cells)
# Detection recall: 0.657624070534 (ratio of correctly detected cells over all erroneous cells in the data)
# Detection F1: 0.712829284981
# -----------------Error Correction Results-----------------
# Destroyed clean cells: 72768 (cell was correct but has been transformed into a wrong value)
# Wrongly cleaned cells: 255241 (cell was wrong but the cleaning was also not correct)
# Undetected cells: 132885 (cell was erroneous but was not touched)
# Number of cells that need yet to be cleaned: 460894 (sum of the 3 cell types above)
# Correction precision = 0.0 (ratio of correctly corrected cells over all changed cells)
# Correction recall = 0.0 (ratio of correctly corrected cells over all erroneous cells in the data)
# Correction F1: 0.0
# u'Number of dirty cells: 388126 (Number of erroneous cells in the data)\n-----------------Error Detection Results-----------------\nNumber of detected cells: 328009 (Number of changed values)\nNumber of Correctly Detected cells: 255241 (cell was correctly identified as an error)\nDetection precision: 0.778152428744 (ratio of correctly detected cells over all detected cells)\nDetection recall: 0.657624070534 (ratio of correctly detected cells over all erroneous cells in the data)\nDetection F1: 0.712829284981\n-----------------Error Correction Results-----------------\nDestroyed clean cells: 72768 (cell was correct but has been transformed into a wrong value)\nWrongly cleaned cells: 255241 (cell was wrong but the cleaning was also not correct)\nUndetected cells: 132885 (cell was erroneous but was not touched)\nNumber of cells that need yet to be cleaned: 460894 (sum of the 3 cell types above)\nCorrection precision = 0.0 (ratio of correctly corrected cells over all changed cells)\nCorrection recall = 0.0 (ratio of correctly corrected cells over all erroneous cells in the data)\nCorrection F1: 0.0'

# %%
print(RESULTS)
# Out:
# [u'Number of dirty cells: 388126 (Number of erroneous cells in the data)\n-----------------Error Detection Results-----------------\nNumber of detected cells: 157259 (Number of changed values)\nNumber of Correctly Detected cells: 115032 (cell was correctly identified as an error)\nDetection precision: 0.731481187086 (ratio of correctly detected cells over all detected cells)\nDetection recall: 0.296377980347 (ratio of correctly detected cells over all erroneous cells in the data)\nDetection F1: 0.421837784318\n-----------------Error Correction Results-----------------\nDestroyed clean cells: 42227 (cell was correct but has been transformed into a wrong value)\nWrongly cleaned cells: 115032 (cell was wrong but the cleaning was also not correct)\nUndetected cells: 273094 (cell was erroneous but was not touched)\nNumber of cells that need yet to be cleaned: 430353 (sum of the 3 cell types above)\nCorrection precision = 0.0 (ratio of correctly corrected cells over all changed cells)\nCorrection recall = 0.0 (ratio of correctly corrected cells over all erroneous cells in the data)\nCorrection F1: 0.0', u'Number of dirty cells: 388126 (Number of erroneous cells in the data)\n-----------------Error Detection Results-----------------\nNumber of detected cells: 294771 (Number of changed values)\nNumber of Correctly Detected cells: 222003 (cell was correctly identified as an error)\nDetection precision: 0.753137181066 (ratio of correctly detected cells over all detected cells)\nDetection recall: 0.571986932079 (ratio of correctly detected cells over all erroneous cells in the data)\nDetection F1: 0.650180041793\n-----------------Error Correction Results-----------------\nDestroyed clean cells: 72768 (cell was correct but has been transformed into a wrong value)\nWrongly cleaned cells: 222003 (cell was wrong but the cleaning was also not correct)\nUndetected cells: 166123 (cell was erroneous but was not touched)\nNumber of cells that need yet to be cleaned: 460894 (sum of the 3 cell types above)\nCorrection precision = 0.0 (ratio of correctly corrected cells over all changed cells)\nCorrection recall = 0.0 (ratio of correctly corrected cells over all erroneous cells in the data)\nCorrection F1: 0.0', u'Number of dirty cells: 388126 (Number of erroneous cells in the data)\n-----------------Error Detection Results-----------------\nNumber of detected cells: 328009 (Number of changed values)\nNumber of Correctly Detected cells: 255241 (cell was correctly identified as an error)\nDetection precision: 0.778152428744 (ratio of correctly detected cells over all detected cells)\nDetection recall: 0.657624070534 (ratio of correctly detected cells over all erroneous cells in the data)\nDetection F1: 0.712829284981\n-----------------Error Correction Results-----------------\nDestroyed clean cells: 72768 (cell was correct but has been transformed into a wrong value)\nWrongly cleaned cells: 255241 (cell was wrong but the cleaning was also not correct)\nUndetected cells: 132885 (cell was erroneous but was not touched)\nNumber of cells that need yet to be cleaned: 460894 (sum of the 3 cell types above)\nCorrection precision = 0.0 (ratio of correctly corrected cells over all changed cells)\nCorrection recall = 0.0 (ratio of correctly corrected cells over all erroneous cells in the data)\nCorrection F1: 0.0', u'Number of dirty cells: 388126 (Number of erroneous cells in the data)\n-----------------Error Detection Results-----------------\nNumber of detected cells: 374976 (Number of changed values)\nNumber of Correctly Detected cells: 302208 (cell was correctly identified as an error)\nDetection precision: 0.805939580133 (ratio of correctly detected cells over all detected cells)\nDetection recall: 0.778633742651 (ratio of correctly detected cells over all erroneous cells in the data)\nDetection F1: 0.792051390247\n-----------------Error Correction Results-----------------\nDestroyed clean cells: 72768 (cell was correct but has been transformed into a wro ...
